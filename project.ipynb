# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\Biswajit Satapathy\Desktop\study\crop.xlsx")

# %%
A=np.array(data)
data
# Out:
#              Region1                    Region2  Year  Crop  Area planted  \
# 0     andhra pradesh                   adilabad  2011  corn       18047.0
# 1     andhra pradesh                   adilabad  2004  corn       26517.0
# 2     andhra pradesh                   adilabad  2006  corn       25057.0
# 3     andhra pradesh                   adilabad  2000  rice       77473.0
# 4     andhra pradesh                   adilabad  1998  corn       29300.0
# 5     andhra pradesh                   adilabad  2009  corn       17899.0
# 6     andhra pradesh                   adilabad  2010  rice       90547.0
# 7     andhra pradesh                   adilabad  2001  rice       77144.0
# 8     andhra pradesh                   adilabad  2000  corn       30498.0
# 9     andhra pradesh                   adilabad  2007  corn       24000.0
# 10    andhra pradesh                   adilabad  2002  corn       28305.0
# 11    andhra pradesh                   adilabad  2005  corn       27153.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label1 = LabelEncoder()
data['Region1'] = label1.fit_transform(data['Region1'])
lab2 = LabelEncoder()
data['Region2'] = lab2.fit_transform(data['Region2'])
lab3 = LabelEncoder()
data['Crop'] = lab3.fit_transform(data['Crop'])

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#       Region1  Region2  Year  Crop  Area planted  Production  Yield
# 0           0        0  2011     0       18047.0       52403   2.90
# 1           0        0  2004     0       26517.0       74482   2.81
# 2           0        0  2006     0       25057.0       78012   3.11
# 3           0        0  2000     1       77473.0      167258   2.16
# 4           0        0  1998     0       29300.0       77900   2.66
# 5           0        0  2009     0       17899.0       68468   3.83
# 6           0        0  2010     1       90547.0      255154   2.82
# 7           0        0  2001     1       77144.0      173741   2.25
# 8           0        0  2000     0       30498.0       95529   3.13
# 9           0        0  2007     0       24000.0       76000   3.17
# 10          0        0  2002     0       28305.0       68877   2.43
# 11          0        0  2005     0       27153.0       92172   3.39
# 12          0        0  1999     1       77368.0      189067   2.44
# ...

# %%
shape=data.shape
row=shape[0]
col=shape[1]
row
# Out:
# 5254

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
Xa=data.iloc[:,:-1]
Ya=data.iloc[:,-1]

# %%
X=np.array(Xa)
Y=np.array(Ya)

# %%
one_column = np.ones((row,1))
X = np.concatenate((one_column, X), axis = 1)

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y,test_size=0.20)

# %%
row1=Xtrain.shape[0]
col1=Xtrain.shape[1]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor

# %%
xtrain=np.array(Xtrain)
ytrain=np.array(Ytrain)
xtest=np.array(Xtest)
ytest=np.array(Ytest)

# %%
lr=LinearRegression()

# %%
rfc=RandomForestRegressor()

# %%
tree = DecisionTreeClassifier(random_state=50)

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
rfc.fit(Xtrain,Ytrain)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rfc.score(xtest, ytest)
# Out:
# 0.8851820253759737

# %%
p=[5233,19,287,2008,1,301005.0,744181]
p=np.array(p)
p=p.reshape(1,-1)
p
# Out:
# array([[5.23300e+03, 1.90000e+01, 2.87000e+02, 2.00800e+03, 1.00000e+00,
#         3.01005e+05, 7.44181e+05]])

# %%
ans=rfc.predict(p)
print(ans)
# Out:
# [2.41]

# %%
lr.score(xtest, ytest)
# Out:
# 0.5116803709039898

# %%
#random forest fits best for the data as compared to logistic regression
